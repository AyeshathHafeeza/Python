# %% [markdown]
# <a href="https://colab.research.google.com/github/AyeshathHafeeza/Python/blob/main/Python_Continue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Continue**

# %%
fruits=['apple','banana','cherry']

for i in fruits:
  if i=="banana":
     print(i)
     continue
  for j in i:
    print(j)
# Out:
# a
# p
# p
# l
# e
# banana
# c
# h
# e
# r
# r
# y
