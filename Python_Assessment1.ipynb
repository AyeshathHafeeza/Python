# %% [markdown]
# <a href="https://colab.research.google.com/github/AyeshathHafeeza/Python/blob/main/Python_Assessment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 01.Write a Python program to take two strings from the user — first name and last name — and print the full name with a space in between using:
#	•	(a) + operator
firstname=input("Enter First name:")
lastname=input("Enter Last name:")
print(firstname+" "+lastname)
# Out:
# Enter First name:Ayeshath
# Enter Last name:Hafeeza
# Ayeshath Hafeeza

# %%
#	•	(b) f-string
firstname=input("Enter First name:")
lastname=input("Enter Last name:")
print(f"{firstname} {lastname}")

# %%
#	•	(c) .format() method
firstname=input("Enter First name:")
lastname=input("Enter Last name:")
print("Full name is {} {}".format(firstname,lastname))

# %%
#02.word1 = "Py"
#word2 = "thon"
#Concatenate these strings to get "Python" and store it in a variable result.Now print result three times in a single line separated by spaces
#(Hint: use multiplication or repetition).
word1 = "Py"
word2 = "thon"
result=word1+word2
print((result+" ")*3)

# %%
#Q3.quote = "Learning Python is fun!"
#Add "Really!" to the end of it without using the + operator.
quote = "Learning Python is fun!"
print(f"{quote} really!")

# %%
#language = "PythonProgramming"
#Write the output for the following (without running the code first — think):
#	1.	language[0:6] ->Python
#	2.	language[-11:-1] ->Programming
#	3.	language[::2] -> Taking every second character
#	4.	language[::-1] -> Reverse string
language = "PythonProgramming"
print(language[0:6])
print(language[-11:-1])
print(language[::2])
print(language[::-1])

# %%
#Extract the word "Programming" from language using slicing only, and store it in a new variable called part.
language = "PythonProgramming"
part=language[6:]
print(part)

# %%
#text = "Data Science with Python"Write a Python statement that:
#	•	Extracts "Science" using slicing.
text = "Data Science with Python"
print(text[5:12])

#	•	Prints only every 2nd character from "Python".
print(text[18::2])

# %%
#Q7. Write a Python program that takes two inputs from the user, both as strings, and adds them as numbers.
#Example:If user inputs "10" and "20", the output should be 30 (not "1020").
a=input("Number1:")
b=input("Number2:")
#Type conversion from string to int
num1=int(a)
num2=int(b)
print(num1+num2)

# %%
x = "123"
y = int(x) + 5 #x value gets converted to int -> y=123+5=128
print(str(y) + "5") #y value gets converted to string -> "128" + "5"=1285
#Explain why that is the output.

# %%
#Write a small Python script that:
# 1.	Take your full name as input.
name="Ayeshath Hafeeza"
#	2.	Extracts your first and last name using slicing.
#	3.	Converts your first name to uppercase and last name to lowercase.
fname=name[:8].upper()
lname=name[9:].lower()
#	4.	Concatenates them with a space in between and prints:
print(fname+" "+lname)
# Out:
# AYESHATH hafeeza
